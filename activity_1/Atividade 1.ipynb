# %% [markdown]
# # Atividade 1

# %%
# Bibliotecas utilizadas
import json
import secrets

import gurobipy as gp
from gurobipy import *

# %%
#
# Funções auxiliares
#

# Range inclusive
def inclrange(min, max):
    return range(min, max + 1)

# Inteiro aleatório entre min e max inclusive
def rand(min, max):
    return min + secrets.randbelow(max - min + 1)

# Salva um arquivo JSON com o dicionário fornecido
def imprimir_json(nome_arquivo, dados):
    with open(nome_arquivo, 'w', encoding='utf-8') as arquivo:
        json.dump(dados, arquivo, ensure_ascii = False, indent = 4)

#
# Configurações
#

limitar_threads = False # 😎 
imprimir_dados = True
imprimir_resultado = True

# %% [markdown]
# ### Limites das variáveis das instâncias
#
# ```
# |J| = {100, 200, 300, 400, 500, 600, 700, 800, 900, 1000}
# |F| ∈ [|J|, 2|J|]
# |L| ∈ [5, 10]
# |M| ∈ [5, 10]
# |P| ∈ [5, 10]
# D_j,p ∈ [10, 20]
# r_m,p,l ∈ [1, 5]
# R_m,f ∈ [800, 1000]
# C_l,f ∈ [80, 100]
# p_p,l,f ∈ [10, 100]
# t_p,f,j ∈ [10, 20]
# ```

# %%
#
# Executar solução
#

def solucionar(J, F, L, M, P, D, r, R, C, cp, ct):
    # Criação do modelo
    modelo = gp.Model(f'Atividade 1 - {len(J)} clientes')
    if limitar_threads:
        modelo.setParam(GRB.Param.Method, 1)
        modelo.setParam(GRB.Param.Threads, 1)

    # Variáveis de decisão
    tonelada_transportada = modelo.addVars(P, F, J, lb = 0, vtype = GRB.CONTINUOUS)
    tonelada_produzida = modelo.addVars(P, L, F, lb = 0, vtype = GRB.CONTINUOUS)
    custo = modelo.addVar(lb = 0, vtype = GRB.CONTINUOUS)
    
    # Função objetivo
    obj = quicksum(quicksum(quicksum(tonelada_produzida.sum(p,l,f) * cp[p][l][f] for p in P) for f in F) for l in L) + quicksum(quicksum(quicksum(tonelada_transportada.sum(p,f,j) * ct[p][f][j] for p in P) for f in F) for j in J)
    modelo.setObjective(obj, GRB.MINIMIZE)
    
    modelo.setParam('TimeLimit', 1800)
        
    for p in P:
        for j in J:
            modelo.addConstr(quicksum(tonelada_transportada.sum(p, f, j) for f in F) == D[j][p])
            
    for p in P:
        for f in F:
            modelo.addConstr(quicksum(tonelada_transportada.sum(p, f, j) for j in J) == quicksum(tonelada_produzida.sum(p, l, f) for l in L))
    
    for f in F:
        for m in M:
            modelo.addConstr(quicksum(quicksum(tonelada_produzida.sum(p, l, f) * r[m][p][l] for p in P) for l in L) <= R[m][f])
            
    for f in F:
        for l in L:
            modelo.addConstr(quicksum(tonelada_produzida.sum(p, l, f) for p in P) <= C[l][f])
    
    modelo.update()
    modelo.write(f'atividade1-{len(J)}_clientes.lp')
    modelo.optimize()
    
    def imprimir_quantidades(custo, status):
        solucao = {
            'custo': custo,
            'status': str(status),
            'tonelada_produzida': [],
            'tonelada_transportada': []
        }
        
        for p in P:
            solucao['tonelada_produzida'].append([])
            for l in L:
                solucao['tonelada_produzida'][p].append([])
                for f in F:
                    solucao['tonelada_produzida'][p][l].append(tonelada_produzida[p, l, f].X)
                    
        for p in P:
            solucao['tonelada_transportada'].append([])
            for f in F:
                solucao['tonelada_transportada'][p].append([])
                for j in J:
                    solucao['tonelada_transportada'][p][f].append(tonelada_transportada[p, f, j].X)
                    
        imprimir_json(f'solucao-{len_J}_clientes.json', solucao)
    
    
    print()
    if modelo.status == GRB.Status.OPTIMAL:
        if imprimir_resultado:
            imprimir_quantidades(modelo.objVal, modelo.Status)
        print('Solução Ótima Encontrada!')
        print(f'Custo: {modelo.objVal}')
    elif modelo.status == GRB.Status.TIME_LIMIT:
        if imprimir_resultado:
            imprimir_quantidades(modelo.objVal, modelo.Status)
        print('Não foi possível encontrar uma solução ótima. Tempo excedido.')
        print('Solução: ')
        print(f'Custo: {modelo.objVal}')
    elif modelo.status == GRB.Status.INFEASIBLE:
        print('Não foi possível encontrar uma solução. Inviável.')
    else:
        print(f'Status do modelo não interpretado: {modelo.Status}')

# %%
#
# Instâncias (dados utilizados, fixos enquanto o notebook está aberto)
#

for len_J in [100 * x for x in inclrange(1, 10)]:
    print(f'Produzindo dados para {len_J} clientes...')
        
    J = [x for x in range(0, len_J)]  # conjunto de clientes
    # Número de...
    len_F = rand(len(J), 2 * len(J))
    F = [x for x in range(0, len_F)]  # fábricas
    
    len_L = rand(5, 10)  
    L = [x for x in range(0, len_L)]  # máquinas
    
    len_M = rand(5, 10)  
    M = [x for x in range(0, len_M)]  # matérias primas
    
    len_P = rand(5, 10)
    P = [x for x in range(0, len_P)]  # produtos
    
    D = []  # D_j,p: demanda de cliente j pelo produto p
    for j in J:
        D.append([])
        for p in P:
            D[j].append([])
            D[j][p] = rand(10, 20)
    
    r = []  # r_m,p,l: quantidade de matéria prima m para produzir produto p na máquina l
    for m in M:
        r.append([])
        for p in P:
            r[m].append([])
            for l in L:
                r[m][p].append([])
                r[m][p][l] = rand(1, 5)
                
    R = []  # R_m,f: quantidade de matéria prima m disponível na fábrica f
    for m in M:
        R.append([])
        for f in F:
            R[m].append([])
            R[m][f] = rand(800, 1000)
            
    C = []  # C_l,f: capacidade de produção da máquina l na fábrica f
    for l in L:
        C.append([])
        for f in F:
            C[l].append([])
            C[l][f] = rand(80, 100)
            
    cp = []  # p_p,l,f -> cp_p,l,f: custo de produção do produto p na máquina l na fábrica f
    for p in P:
        cp.append([])
        for l in L:
            cp[p].append([])
            for f in F:
                cp[p][l].append([])
                cp[p][l][f] = rand(10, 100)
    
    ct = []  # t_p,f,j -> ct_p,f,j: custo de transporte do produto p da fábrica f ao consumidor j
    for p in P:
        ct.append([])
        for f in F:
            ct[p].append([])
            for j in J:
                ct[p][f].append([])
                ct[p][f][j] = rand(10, 20)
    
    instancia = {
        'J': J,
        'F': F,
        'L': L,
        'M': M,
        'P': P,
        'D': D,
        'r': r,
        'R': R,
        'C': C,
        'cp': cp,
        'ct': ct
    }
    
    if imprimir_dados:
        imprimir_json(f'instancia-{len_J}_clientes.json', instancia)
    print(f'Solucionando para {len_J} clientes...')
    solucionar(**instancia)
    print('\n\n\n')
# Out:
# Produzindo dados para 100 clientes...
# Solucionando para 100 clientes...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-05-27
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 4300 rows, 136081 columns and 322560 nonzeros
# Model fingerprint: 0xd828356f
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.11s
# Presolved: 4300 rows, 136080 columns, 322560 nonzeros
#
# Ordering time: 0.10s
#
# Barrier statistics:
#  AA' NZ     : 1.514e+05
#  Factor NZ  : 9.098e+05 (roughly 60 MB of memory)
#  Factor Ops : 4.674e+08 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.27 seconds (0.25 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 4660 iterations and 0.27 seconds (0.30 work units)
# Optimal objective  2.109030000e+05
#
# Solução Ótima Encontrada!
# Custo: 210903.0
#
#
#
#
# Produzindo dados para 200 clientes...
# Solucionando para 200 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 10975 rows, 621001 columns and 1452000 nonzeros
# Model fingerprint: 0xf9331067
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.66s
# Presolved: 10975 rows, 621000 columns, 1452000 nonzeros
#
# Ordering time: 0.40s
#
# Barrier statistics:
#  AA' NZ     : 6.941e+05
#  Factor NZ  : 4.164e+06 (roughly 300 MB of memory)
#  Factor Ops : 4.523e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.08053424e+09  0.00000000e+00  3.99e+04 0.00e+00  4.59e+03     1s
#    1   1.48170201e+08 -4.65747628e+06  5.48e+03 4.26e-14  6.41e+02     2s
#    2   1.14741085e+06 -1.02337009e+06  3.91e-11 4.26e-14  3.46e+00     2s
#    3   7.83274085e+05  3.83774020e+05  2.20e-13 3.02e-14  6.37e-01     2s
#    4   6.09770176e+05  4.26732849e+05  2.74e-13 4.26e-14  2.92e-01     2s
#    5   5.44102085e+05  4.58482448e+05  7.91e-12 1.31e-13  1.36e-01     2s
#
# Barrier performed 5 iterations in 2.29 seconds (2.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 12956 iterations and 2.29 seconds (1.93 work units)
# Optimal objective  4.835766968e+05
#
# Solução Ótima Encontrada!
# Custo: 483576.6968325792
#
#
#
#
# Produzindo dados para 300 clientes...
# Solucionando para 300 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 9000 rows, 736801 columns and 1557600 nonzeros
# Model fingerprint: 0x60244066
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.83s
# Presolved: 9000 rows, 736800 columns, 1557600 nonzeros
#
# Ordering time: 1.22s
#
# Barrier statistics:
#  AA' NZ     : 7.668e+05
#  Factor NZ  : 3.189e+06 (roughly 300 MB of memory)
#  Factor Ops : 3.042e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.21778865e+09  0.00000000e+00  4.15e+04 0.00e+00  4.41e+03     2s
#    1   1.03572797e+08 -3.93816649e+06  3.55e+03 4.26e-14  3.85e+02     3s
#    2   1.17938028e+06 -8.31120991e+05  4.04e-01 4.26e-14  2.74e+00     3s
#
# Barrier performed 2 iterations in 2.60 seconds (2.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 10853 iterations and 2.61 seconds (2.33 work units)
# Optimal objective  5.489578000e+05
#
# Solução Ótima Encontrada!
# Custo: 548957.8
#
#
#
#
# Produzindo dados para 400 clientes...
# Solucionando para 400 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 14300 rows, 1320201 columns and 2898000 nonzeros
# Model fingerprint: 0x9d7bcc3e
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns
# Presolve time: 1.78s
# Presolved: 14300 rows, 1320200 columns, 2898000 nonzeros
#
# Ordering time: 1.87s
#
# Barrier statistics:
#  AA' NZ     : 1.396e+06
#  Factor NZ  : 5.653e+06 (roughly 600 MB of memory)
#  Factor Ops : 6.315e+09 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.06658771e+09  0.00000000e+00  4.50e+04 0.00e+00  4.18e+03     4s
#    1   2.14796761e+08 -6.14057152e+06  4.75e+03 4.26e-14  4.46e+02     4s
#    2   1.78702617e+06 -1.48653970e+06  1.20e-11 4.26e-14  2.46e+00     5s
#    3   1.28322482e+06  7.24791923e+05  2.56e-13 3.38e-14  4.20e-01     5s
#
# Barrier performed 3 iterations in 4.81 seconds (5.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 15855 iterations and 4.83 seconds (4.04 work units)
# Optimal objective  8.485655338e+05
#
# Solução Ótima Encontrada!
# Custo: 848565.5338460051
#
#
#
#
# Produzindo dados para 500 clientes...
# Solucionando para 500 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 20007 rows, 3432486 columns and 7034895 nonzeros
# Model fingerprint: 0x455f621a
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns
# Presolve time: 5.62s
# Presolved: 20007 rows, 3432485 columns, 7034895 nonzeros
#
# Ordering time: 6.70s
#
# Barrier performed 0 iterations in 28.91 seconds (10.99 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 888157 iterations and 28.95 seconds (18.80 work units)
# Optimal objective  1.069403978e+06
#
# Solução Ótima Encontrada!
# Custo: 1069403.9777777777
#
#
#
#
# Produzindo dados para 600 clientes...
# Solucionando para 600 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 24625 rows, 4567676 columns and 9398725 nonzeros
# Model fingerprint: 0x9ec6c310
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 1 columns
# Presolve time: 9.43s
# Presolved: 24625 rows, 4567675 columns, 9398725 nonzeros
#
# Ordering time: 5.37s
#
# Barrier performed 0 iterations in 42.98 seconds (16.06 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 1073334 iterations and 43.04 seconds (29.45 work units)
# Optimal objective  1.278210877e+06
#
# Solução Ótima Encontrada!
# Custo: 1278210.8772727272
#
#
#
#
# Produzindo dados para 700 clientes...
# Solucionando para 700 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 28592 rows, 5433777 columns and 11350384 nonzeros
# Model fingerprint: 0xfbae2d8e
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns (presolve time = 11s) ...
# Presolve removed 0 rows and 1 columns
# Presolve time: 14.91s
# Presolved: 28592 rows, 5433776 columns, 11350384 nonzeros
#
# Ordering time: 5.07s
# Elapsed ordering time = 5s
# Elapsed ordering time = 10s
# Ordering time: 12.09s
#
# Barrier performed 0 iterations in 63.84 seconds (29.81 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 38929 iterations and 63.90 seconds (45.50 work units)
# Optimal objective  1.705572961e+06
#
# Solução Ótima Encontrada!
# Custo: 1705572.961172161
#
#
#
#
# Produzindo dados para 800 clientes...
# Solucionando para 800 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 21660 rows, 4081807 columns and 8411454 nonzeros
# Model fingerprint: 0xeb68424f
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns (presolve time = 5s) ...
# Presolve removed 0 rows and 1 columns
# Presolve time: 7.62s
# Presolved: 21660 rows, 4081806 columns, 8411454 nonzeros
#
# Ordering time: 6.06s
# Elapsed ordering time = 6s
# Ordering time: 9.31s
#
# Barrier performed 0 iterations in 45.82 seconds (23.63 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 29276 iterations and 45.89 seconds (35.50 work units)
# Optimal objective  1.483670695e+06
#
# Solução Ótima Encontrada!
# Custo: 1483670.6948621545
#
#
#
#
# Produzindo dados para 900 clientes...
# Solucionando para 900 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 23256 rows, 4720261 columns and 9659340 nonzeros
# Model fingerprint: 0xce446642
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 1 columns
# Presolve time: 9.62s
# Presolved: 23256 rows, 4720260 columns, 9659340 nonzeros
#
# Ordering time: 7.57s
#
# Barrier performed 0 iterations in 48.70 seconds (22.09 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Solved in 1203471 iterations and 48.96 seconds (34.41 work units)
# Optimal objective  1.387113537e+06
#
# Solução Ótima Encontrada!
# Custo: 1387113.5372549023
#
#
#
#
# Produzindo dados para 1000 clientes...
# Solucionando para 1000 clientes...
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[arm])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 37050 rows, 10412101 columns and 21196800 nonzeros
# Model fingerprint: 0x81d9b4fc
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 0 rows and 1 columns (presolve time = 7s) ...
# Presolve removed 0 rows and 1 columns (presolve time = 11s) ...
# Presolve removed 0 rows and 1 columns (presolve time = 31s) ...
# Presolve removed 0 rows and 1 columns (presolve time = 36s) ...
# Presolve removed 0 rows and 1 columns
# Presolve time: 43.00s
# Presolved: 37050 rows, 10412100 columns, 21196800 nonzeros
#
# Elapsed ordering time = 5s
# Ordering time: 20.85s
# Elapsed ordering time = 21s
# Elapsed ordering time = 25s
# Elapsed ordering time = 30s
# Elapsed ordering time = 35s
# Elapsed ordering time = 40s
# Ordering time: 43.51s
#
# Barrier statistics:
#  AA' NZ     : 1.056e+07
#  Factor NZ  : 5.058e+07 (roughly 5.0 GB of memory)
#  Factor Ops : 1.969e+11 (roughly 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.47409824e+10  0.00000000e+00  1.60e+05 0.00e+00  3.85e+03   242s
#    1   9.35072242e+08 -1.30610678e+07  1.01e+04 4.26e-14  2.49e+02   250s
#    2   3.90252534e+06 -2.15297374e+06  1.08e-02 4.26e-14  5.80e-01   261s
#    3   2.79555426e+06  1.68119069e+06  1.09e-03 4.26e-14  1.07e-01   274s
#    4   2.52871261e+06  1.72743482e+06  1.51e-03 4.26e-14  7.68e-02   286s
#    5   2.34721357e+06  1.75540831e+06  1.70e-03 2.84e-14  5.67e-02   298s
#    6   2.25219357e+06  1.76800819e+06  2.18e-03 2.84e-14  4.64e-02   307s
#    7   2.18267896e+06  1.77750731e+06  5.09e-03 2.84e-14  3.88e-02   315s
#    8   2.16644964e+06  1.78370024e+06  4.84e-03 2.84e-14  3.67e-02   329s
#    9   2.15065861e+06  1.78885016e+06  4.60e-03 2.84e-14  3.47e-02   339s
#   10   2.10798914e+06  1.80103735e+06  3.94e-03 2.84e-14  2.94e-02   353s
#   11   2.08561530e+06  1.81092153e+06  3.60e-03 2.84e-14  2.63e-02   372s
#   12   2.03398768e+06  1.81863801e+06  2.82e-03 2.84e-14  2.06e-02   392s
#   13   1.99398229e+06  1.82145599e+06  2.25e-03 2.84e-14  1.65e-02   406s
#   14   1.89315729e+06  1.82810111e+06  8.47e-04 2.84e-14  6.24e-03   426s
#   15   1.86640833e+06  1.82893947e+06  4.82e-04 2.84e-14  3.59e-03   439s
#   16   1.83096344e+06  1.82931949e+06  4.45e-06 4.26e-14  1.58e-04   459s
#   17   1.82933762e+06  1.82932854e+06  1.88e-09 4.26e-14  8.70e-07   470s
#   18   1.82932881e+06  1.82932880e+06  1.17e-09 2.84e-14  8.70e-10   481s
#
# Barrier solved model in 18 iterations and 481.10 seconds (193.39 work units)
# Optimal objective 1.82932881e+06
#
# Crossover log...
#
#    10390 DPushes remaining with DInf 0.0000000e+00               489s
#       73 DPushes remaining with DInf 0.0000000e+00               491s
#        0 DPushes remaining with DInf 0.0000000e+00               492s
#
#   107431 PPushes remaining with PInf 0.0000000e+00               492s
#        0 PPushes remaining with PInf 0.0000000e+00               494s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.5202063e-14    494s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#   117823    1.8293288e+06   0.000000e+00   0.000000e+00    510s
#
# Solved with dual simplex
# Solved in 54061 iterations and 516.30 seconds (150.17 work units)
# Optimal objective  1.829328800e+06
#
# Solução Ótima Encontrada!
# Custo: 1829328.7999999996
